# %%
import requests
import json
import pandas as pd
import pymssql
import time
from sqlalchemy import create_engine

conn2 = pymssql.connect(server='121.42.61.195', user='test', password='tes@t123456#pwd2018&',database='izhaowoDataCenter', login_timeout=60, charset='UTF-8', port='1433')

#策划师id，策划师地址id
sql1 = """select [worker_id] ,
[address_id]
 from [izhaowoDataCenter].[dbo].[tb_worker_location] WHERE [address_id] is not null"""

#酒店地址，策划师住址对应的经纬度
sql2 = """select * from [izhaowoDataCenter].[dbo].[tb_hotel]"""
print('开始读取数据...')
planner_address_id = pd.read_sql(sql1,conn2)
hotel_address = pd.read_sql(sql2,conn2)
print('数据读取完毕...')
# Out:
# 开始读取数据...
# 数据读取完毕...

# %%
print (planner_address.shape, len(planner_address_id.worker_id.unique()))
print (planner_address.shape, len(planner_address_id.address_id.unique()))

planner_address_id.head()
# Out:
# (602, 6) 602
# (602, 6) 530
#                               worker_id                            address_id
# 0  55b41960-2117-47b1-ae36-e7f263355e67  05426d1c-37f0-4168-a3e8-d4e3a716a2d6
# 1  89f6e997-0545-46a2-8e5b-ec0dfa023b5f  fecd1f2a-dbc2-4a2b-b16e-82996e79bac8
# 2  fcd0208f-dbe4-4068-a387-9a2eb058f229  ddc7a64f-7bed-44d4-81ec-dce23d44fa52
# 3  226cbf72-c43e-4cb5-9cc1-6a935969fcf8  a31df1ec-edde-499c-9ac0-c8e50008261b
# 4  b53c4561-a4c8-4cda-9422-5f68c3b52a67  b4de79a0-5c02-4fd9-bc47-154cf3f56238

# %%
hotel_address.head()
# Out:
#                                      id     amap_id            name  \
# 0  000e9ca4-ba48-47fb-a964-55d86e305edd  B001C7XMB9        成都理工大学宿舍
# 1  0012a9f7-9995-426a-b3f9-742fb84c5f2f  B001794KRX     重庆典雅华美达广场酒店
# 2  001e3493-8b7b-4023-b72f-b2c17d6441e1  B0FFHU2KFF  家和印象大饭店(玫瑰天街店)
# 3  006077f2-3ce2-406e-8cdd-d9ab1c326b0a  B0FFIIT4UG        荷香苑(西南门)
# 4  0063ec5d-ffcb-4066-9d84-7d7b6c9176de  B0017875B5            重庆会馆
#
#                   address province city zone   longitude   latitude  \
# 0               包家巷127号1栋      四川省  成都市  青羊区  104.049870  30.659664
# 1  鱼洞云锦路1号典雅天城附近(轻轨鱼洞站对面)      重庆市  重庆市  巴南区  106.502614  29.373285
# 2          家和印象大饭店(玫瑰天街店)      重庆市  重庆市  渝北区  106.544773  29.642889
# 3                 成环路东50米      四川省  成都市  金堂县  104.423045  30.823347
# 4  龙湖水晶郦城旁新南路162号龙湖水晶星座1层      重庆市  重庆市  渝北区  106.504246  29.601875
#
#                 ctime               utime
# 0 2019-05-01 15:24:11 2019-05-13 22:11:07
# 1 2018-04-02 11:35:59 2019-05-13 22:15:20
# ...

# %%
hotel_address = hotel_address.rename(columns={'id':'address_id'})
print (hotel_address.shape, len(hotel_address.address_id.unique()))
hotel_address.head()
# Out:
# (2351, 11) 2351
#                              address_id     amap_id            name  \
# 0  000e9ca4-ba48-47fb-a964-55d86e305edd  B001C7XMB9        成都理工大学宿舍
# 1  0012a9f7-9995-426a-b3f9-742fb84c5f2f  B001794KRX     重庆典雅华美达广场酒店
# 2  001e3493-8b7b-4023-b72f-b2c17d6441e1  B0FFHU2KFF  家和印象大饭店(玫瑰天街店)
# 3  006077f2-3ce2-406e-8cdd-d9ab1c326b0a  B0FFIIT4UG        荷香苑(西南门)
# 4  0063ec5d-ffcb-4066-9d84-7d7b6c9176de  B0017875B5            重庆会馆
#
#                   address province city zone   longitude   latitude  \
# 0               包家巷127号1栋      四川省  成都市  青羊区  104.049870  30.659664
# 1  鱼洞云锦路1号典雅天城附近(轻轨鱼洞站对面)      重庆市  重庆市  巴南区  106.502614  29.373285
# 2          家和印象大饭店(玫瑰天街店)      重庆市  重庆市  渝北区  106.544773  29.642889
# 3                 成环路东50米      四川省  成都市  金堂县  104.423045  30.823347
# 4  龙湖水晶郦城旁新南路162号龙湖水晶星座1层      重庆市  重庆市  渝北区  106.504246  29.601875
#
#                 ctime               utime
# 0 2019-05-01 15:24:11 2019-05-13 22:11:07
# 1 2018-04-02 11:35:59 2019-05-13 22:15:20
# ...

# %%
outer = planner_address_id.merge(hotel_address,on='address_id',how='outer')
outer['worker_id'] = outer['worker_id'].fillna(0)
outer.tail()
# Out:
#      worker_id                            address_id     amap_id       name  \
# 2418         0  ff55b770-9d91-4215-85d6-b6bd726294ab  B001786Q1Z   锦达园礼宴大酒楼
# 2419         0  ffb6a6b8-a0e7-49f0-a183-99227ea59b5a  B001C7XQD9     基督教上翔堂
# 2420         0  ffbfd9d5-ba07-4975-bdbc-9c69c8621121  B001C8O7UW  成都高新豪生大酒店
# 2421         0  ffc32e60-c902-4d5a-9273-b446d7dcb966  B0FFIMTRRZ       璞莲山庄
# 2422         0  ffc755f5-8d27-4157-85f3-0a808948b7cf  B07290N5NQ    青神江湾神木园
#
#                    address province city  zone   longitude   latitude  \
# 2418  二郎科技新城迎宾大道35号(居然之家旁)      重庆市  重庆市  九龙坡区  106.463406  29.509812
# 2419                上翔街20号      四川省  成都市   青羊区  104.070468  30.661136
# 2420          成都高新区天泰路338号      四川省  成都市   武侯区  104.069021  30.590069
# 2421                            四川省  成都市   崇州市  103.561407   30.63803
# 2422                外南街73号      四川省  眉山市   青神县  103.846825  29.823503
#
#                    ctime               utime
# ...

# %%
print (outer.shape, len(outer.address_id.unique()))
print (outer.longitude.isnull().sum())
# Out:
# (2423, 12) 2351
# 0

# %%
outer.tail()
# Out:
#      worker_id                            address_id     amap_id       name  \
# 2418         0  ff55b770-9d91-4215-85d6-b6bd726294ab  B001786Q1Z   锦达园礼宴大酒楼
# 2419         0  ffb6a6b8-a0e7-49f0-a183-99227ea59b5a  B001C7XQD9     基督教上翔堂
# 2420         0  ffbfd9d5-ba07-4975-bdbc-9c69c8621121  B001C8O7UW  成都高新豪生大酒店
# 2421         0  ffc32e60-c902-4d5a-9273-b446d7dcb966  B0FFIMTRRZ       璞莲山庄
# 2422         0  ffc755f5-8d27-4157-85f3-0a808948b7cf  B07290N5NQ    青神江湾神木园
#
#                    address province city  zone   longitude   latitude  \
# 2418  二郎科技新城迎宾大道35号(居然之家旁)      重庆市  重庆市  九龙坡区  106.463406  29.509812
# 2419                上翔街20号      四川省  成都市   青羊区  104.070468  30.661136
# 2420          成都高新区天泰路338号      四川省  成都市   武侯区  104.069021  30.590069
# 2421                            四川省  成都市   崇州市  103.561407   30.63803
# 2422                外南街73号      四川省  眉山市   青神县  103.846825  29.823503
#
#                    ctime               utime
# ...

# %%
print (outer.longitude.isnull().sum(), outer.latitude.isnull().sum())
print (outer.shape, len(outer.address_id.unique()))
# Out:
# 0 0
# (2423, 12) 2351

# %%
#策划师地址经纬度
planner_address = outer[outer['worker_id']!=0]
planner_address['经纬度'] = planner_address['longitude']+','+planner_address['latitude']
planner_address = planner_address[['worker_id','province','city','zone','name','经纬度']]
planner_address = planner_address.rename(columns={'province':'策划师省','city':'策划师市','zone':'策划师区','name':'地址','经纬度':'策划师经纬度'})

#酒店地址经纬度
hotel_address_ = outer[outer['worker_id']==0]
hotel_address_['经纬度'] = hotel_address_['longitude']+','+hotel_address_['latitude']
hotel_address_ = hotel_address_[['province','city','zone','name','经纬度']]
hotel_address_ = hotel_address_.rename(columns={'province':'酒店省','city':'酒店市','zone':'酒店区','name':'酒店名字','经纬度':'酒店经纬度'})
print('数据整理完毕')
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# d:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# 数据整理完毕...

# %%
print (planner_address.shape)
print (hotel_address_.shape)
# Out:
# (602, 6)
# (1821, 5)

# %%
#酒店经纬度
def get_hotel_longitude_latitude(start,end):
    s = ''
    for i in hotel_address_['酒店经纬度'].iloc[start:end]:
        s+=i+'|'
    s = s[:-1]
    return s

#批量传入经纬度，返回对应经纬度的距离/m
def distance(s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,d1):
    # key
    key = 'e242f983b82743b7634da6d87ea64123'

    # 主请求
    url = "https://restapi.amap.com/v3/batch?key=e242f983b82743b7634da6d87ea64123"

    # 子请求
    # url1="https://restapi.amap.com/v3/direction/driving?origin=%s&destination=%s&extensions=base&output=JSON&key=%s"%(str(origin).strip(),str(destination).strip(),key)
    # s1为100百个酒店的经纬度中间用|分割
    # d1为策划师的地址经纬度
    data = {"ops": [{"url": "/v3/distance?origins={s1}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s1=s1, d1=d1)},
                    {"url": "/v3/distance?origins={s2}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s2=s2, d1=d1)},
                    {"url": "/v3/distance?origins={s3}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s3=s3, d1=d1)},
                    {"url": "/v3/distance?origins={s4}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s4=s4, d1=d1)},
                    {"url": "/v3/distance?origins={s5}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s5=s5, d1=d1)},
                    {"url": "/v3/distance?origins={s6}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s6=s6, d1=d1)},
                    {"url": "/v3/distance?origins={s7}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s7=s7, d1=d1)},
                    {"url": "/v3/distance?origins={s8}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s8=s8, d1=d1)},
                    {"url": "/v3/distance?origins={s9}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s9=s9, d1=d1)},
                    {"url": "/v3/distance?origins={s10}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s10=s10, d1=d1)},
                    {"url": "/v3/distance?origins={s11}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s11=s11, d1=d1)},
                    {"url": "/v3/distance?origins={s12}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s12=s12, d1=d1)},
                    {"url": "/v3/distance?origins={s13}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s13=s13, d1=d1)},
                    {"url": "/v3/distance?origins={s14}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s14=s14, d1=d1)},
                    {"url": "/v3/distance?origins={s15}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s15=s15, d1=d1)},
                    {"url": "/v3/distance?origins={s16}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s16=s16, d1=d1)},
                    {"url": "/v3/distance?origins={s17}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s17=s17, d1=d1)},
                    {"url": "/v3/distance?origins={s18}&destination={d1}&output=JSON&key=e242f983b82743b7634da6d87ea64123".format(s18=s18, d1=d1)}
                    ]
            }
    headers = {'content-type': "application/json"}
    data = requests.post(url, data=json.dumps(data), headers=headers)
    return data.json()

if __name__ == '__main__':
    s1 = get_hotel_longitude_latitude(0,100)
    s2 = get_hotel_longitude_latitude(100,200)
    s3 = get_hotel_longitude_latitude(200,300)
    s4 = get_hotel_longitude_latitude(300,400)
    s5 = get_hotel_longitude_latitude(400,500)
    s6 = get_hotel_longitude_latitude(500,600)
    s7 = get_hotel_longitude_latitude(600,700)
    s8 = get_hotel_longitude_latitude(700,800)
    s9 = get_hotel_longitude_latitude(800,900)
    s10 = get_hotel_longitude_latitude(900,1000)
    s11 = get_hotel_longitude_latitude(1000,1100)
    s12 = get_hotel_longitude_latitude(1100,1200)
    s13 = get_hotel_longitude_latitude(1200,1300)
    s14 = get_hotel_longitude_latitude(1300,1400)
    s15 = get_hotel_longitude_latitude(1400,1500)
    s16 = get_hotel_longitude_latitude(1500,1600)
    s17 = get_hotel_longitude_latitude(1600,1700)
    s18 = get_hotel_longitude_latitude(1700,1800)
    #策划师经纬度
    for i in range(0,len(planner_address['策划师经纬度'])):
        print('计算第%s个策划师到1800个酒店的距离...'%(i))
        d1 = planner_address['策划师经纬度'][i]
        data = hotel_address_.iloc[:1800,:]
        data['worker_id'] = planner_address['worker_id'][i]
        data['策划师省'] = planner_address['策划师省'][i]
        data['策划师市'] = planner_address['策划师市'][i]
        data['策划师区'] = planner_address['策划师区'][i]
        data['地址'] = planner_address['地址'][i]
        data['策划师经纬度'] = planner_address['策划师经纬度'][i]
        data_result = distance(s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16,s17,s18,d1)
        print (data_result)
        stop
        l =[]
        for i in range(0,18):
            for j in range(0,100):
                l.append(data_result[i]['body']['results'][j]['distance'])
        data['distance'] = l
        print('第%s个策划师到1800个酒店的距离计算完毕,正在储存数据库...')
        # yconnect = create_engine('mysql+mysqldb://root:123456@115.29.45.77:3306/izhaowo_worker?charset=utf8')
        # pd.io.sql.to_sql(data, 'planner_hotel_distance1', yconnect, schema='izhaowo_worker', if_exists='append',index=False)
        # print('储存完毕...')
# Out:
# 计算第0个策划师到1800个酒店的距离...
# d:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# d:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# d:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
